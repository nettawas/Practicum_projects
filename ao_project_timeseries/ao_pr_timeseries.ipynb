# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# Привет, меня зовут Александр Куимов. Я буду ревьюером твоего проекта. Ты можешь обращаться ко мне на "ты"😏 Надеюсь, тебя также не смутит, если я буду обращаться к тебе на "ты", но если это неудобно, обязательно скажи об этом!
#
# **Пожалуйста, не перемещай, не изменяй и не удаляй мои комментарии**, они будут особенно полезны для нашей работы в случае повторной проверки проекта.
#
# Прошу реагировать на все мои комментарии, по которым ты вносишь правки в проект, своими комментариями по шаблону, показанному чуть ниже. На каждое мое замечание нужно отвечать комментарием студента в маркдаун ячейке **ниже моей. Это нужно, чтобы не создавалась путаница**.😉
#
# Ты можешь найти мои комментарии, обозначенные <font color='green'>зеленым</font>, <font color='gold'>же лтым</font> и <font color='red'>красным</font> цветами, например:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> В случае, если решение на отдельном шаге является полностью правильным.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b> В случае, когда решение на отдельном шаге станет еще лучше, если внести небольшие коррективы.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#  В случае, когда решение на отдельном шаге требует существенной переработки и внесения правок. Напоминаю, что проект не может быть принят с первого раза, если ревью содержит комментарии, рекомендующие доработать шаги.
# </div>
#
#
# <br/>
# <div class="alert alert-info">
# <h2> Комментарий студента: <a class="tocSkip"> </h2>
#
# <b>👋:</b> В такой цветовой ячейке - образце я прошу тебя оставлять твои комментарии. **Обязательно сохрани в нем заголовок "Комментарий студента" в каждой твоей ячейке**. Если исправляешь проект во второй раз и далее, не забывай пожалуйста указывать номер итерации, например, "Комментарий студента 2". У меня к этому моменту уже появится нумерация в моих комментариях.
# </div>
#
# <br/>
#
# Увидев у тебя неточность, в первый раз я лишь укажу на ее наличие и дам тебе возможность самому найти и исправить ее. На реальной работе твой руководитель будет поступать также, и я пытаюсь подготовить тебя именно к работе датасаентистом. Но если ты пока не справишься с такой задачей - при следующей проверке я дам более точную подсказку!🤓
#
#    **Если у тебя будут возникают какие-то сложности, связанные с выполнением этого проекта**, то я смогу отвечать тебе на вопросы только в ходе ревью до 24 часов на основании соглашения об уровне услуг SLA (это может быть любое время суток, даже ночью), и к сожалению, каждые из таких ревью расходуют доступные иттерации (их всего 6).
# Лучшее решение в подобных случаях - обратиться за помощью к преподавателю по проектам в треде для получения оперативных консультаций. На всякий случай акцентирую, что преподаватель отвечает в тредах, а в личку не отвечает. В редких случаях может возникнуть ситуация, когда преподаватель не ответил вовремя, в таком случае рекомендую связаться с куратором для оперативного решения вопроса.
#
#    **Если у тебя будут возникают вопросы, которые не касаются проекта и моих комментариев в нем**, а касаются теории и спринта, то я смогу кратко тебе ответить, а подробнее на вопрос тебе ответит преподаватель и по запросу сможет подобрать материал адекватный текущему прогрессу курса (только нужно написать ему в тред) 🤓

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка" data-toc-modified-id="Подготовка-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка</a></span></li><li><span><a href="#Анализ" data-toc-modified-id="Анализ-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Анализ</a></span></li><li><span><a href="#Обучение" data-toc-modified-id="Обучение-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Обучение</a></span></li><li><span><a href="#Тестирование" data-toc-modified-id="Тестирование-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Тестирование</a></span></li><li><span><a href="#Итоги-проекта" data-toc-modified-id="Итоги-проекта-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Итоги проекта</a></span></li><li><span><a href="#Чек-лист-проверки" data-toc-modified-id="Чек-лист-проверки-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Чек-лист проверки</a></span></li></ul></div>

# %% [markdown]
# #  Прогнозирование заказов такси

# %% [markdown]
# Компания «Чётенькое такси» собрала исторические данные о заказах такси в аэропортах. Чтобы привлекать больше водителей в период пиковой нагрузки, нужно спрогнозировать количество заказов такси на следующий час. Постройте модель для такого предсказания.
#
# Значение метрики *RMSE* на тестовой выборке должно быть не больше 48.
#
# Вам нужно:
#
# 1. Загрузить данные и выполнить их ресемплирование по одному часу.
# 2. Проанализировать данные.
# 3. Обучить разные модели с различными гиперпараметрами. Сделать тестовую выборку размером 10% от исходных данных.
# 4. Проверить данные на тестовой выборке и сделать выводы.
#
#
# Данные лежат в файле `taxi.csv`. Количество заказов находится в столбце `num_orders` (от англ. *number of orders*, «число заказов»).

# %% [markdown]
# ## Подготовка

# %%
# Импортируем библиотеки для работы с данными и визуализацией
import pandas as pd 
import seaborn as sns 
from matplotlib import pyplot as plt 

# Импортируем инструмент для анализа временных рядов
from statsmodels.tsa.seasonal import seasonal_decompose 

# Импортируем инструменты машинного обучения
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error  
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor 

# Инструмент для подбора гиперпараметров
from sklearn.model_selection import GridSearchCV 

# Импортируем градиентные бустинговые модели
from catboost import CatBoostRegressor 
import lightgbm as lgb

# Кросс-валидация для временных рядов
from sklearn.model_selection import TimeSeriesSplit  

# Отключаем предупреждения, чтобы они не мешали анализу
import warnings
warnings.filterwarnings('ignore')

# %%
# Загружаем данные в DataFrame, назначаем первый столбец (даты) индексом и сразу приводим его к формату datetime
df = pd.read_csv('/datasets/taxi.csv', index_col=[0], parse_dates=[0])

# Выведем первые пять строк, чтобы ознакомиться со структурой данных
display(df.head())
# Out:
#                      num_orders
# datetime
# 2018-03-01 00:00:00           9
# 2018-03-01 00:10:00          14
# 2018-03-01 00:20:00          28
# 2018-03-01 00:30:00          20
# 2018-03-01 00:40:00          32

# %%
# Проверим общую информацию о датасете: количество строк, типы данных, наличие пропусков
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 26496 entries, 2018-03-01 00:00:00 to 2018-08-31 23:50:00
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   num_orders  26496 non-null  int64
# dtypes: int64(1)
# memory usage: 414.0 KB

# %%
# Проверим, есть ли пропущенные значения в таблице
missing_values = df.isna().sum()
print("Количество пропущенных значений:\n", missing_values)
# Out:
# Количество пропущенных значений:
#  num_orders    0
# dtype: int64

# %%
# Проверим, является ли индекс монотонно возрастающим (важно для временных рядов)
print("Индекс монотонный:", df.index.is_monotonic)
# Out:
# Индекс монотонный: True

# %%
# Ресемплируем данные с агрегированием по часу (суммируем количество заказов за каждый час)
df = df.resample('1H').sum()

# %%
# Выведем несколько строк после ресемплирования, чтобы убедиться в корректности
display(df.head())
# Out:
#                      num_orders
# datetime
# 2018-03-01 00:00:00         124
# 2018-03-01 01:00:00          85
# 2018-03-01 02:00:00          71
# 2018-03-01 03:00:00          66
# 2018-03-01 04:00:00          43

# %% [markdown]
# **Промежуточный вывод:**
#
# - Данные загружены успешно, содержат 26 496 записей за период с 1 марта 2018 года по 31 августа 2018 года.
#
#
# - Пропущенные значения отсутствуют, что упрощает дальнейшую работу и исключает необходимость их обработки.
#
#
# - Индекс данных представлен в формате datetime и является монотонно возрастающим, что критично для временных рядов.
#
#
# - Ресемплирование данных по одному часу выполнено корректно — теперь данные агрегированы и показывают суммарное количество заказов за каждый час.
#
#
# - Первые строки после ресемплирования подтверждают правильность изменения структуры данных — каждый временной штамп теперь соответствует количеству заказов за конкретный час.

# %% [markdown]
#  <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:  </b>
#
# С данными познакомились, проведен первичный аналитический осмотр!) Отлично, что проведено ресемплирование с использованием суммы. Полученная информация поможет нам в дальнейшем с предобработкой данных

# %% [markdown]
# ## Анализ

# %%
# Устанавливаем стиль графиков

sns.set_style("whitegrid")
sns.set_palette("pastel")
plt.rcParams.update({'figure.figsize': (15, 5), 'axes.grid': True})

# %%
# Функция для построения линейных графиков с подписями осей
def lineplot(data, title, xlabel='Дата', ylabel='Количество заказов'):
    plt.figure(figsize=(15, 5))
    plt.plot(data, color=sns.color_palette("pastel")[2], linewidth=2)  
    plt.title(title, fontsize=14, fontweight='bold', color='darkblue')  
    plt.xlabel(xlabel, fontsize=12, color='black')  
    plt.ylabel(ylabel, fontsize=12, color='black') 
    plt.xticks(rotation=25) 
    plt.show()

# Разделяем временной ряд на компоненты: тренд, сезонность, шум

decomposed = seasonal_decompose(df, period=24)  # Учитываем суточную сезонность

# Строим графики 
lineplot(decomposed.trend, 'Тренд заказов такси')
lineplot(decomposed.trend.rolling(24*7).mean(), 'Тренд (сглаженный, 7 дней)')
lineplot(decomposed.seasonal.tail(24*7), 'Суточная сезонность')
lineplot(decomposed.resid, 'Остатки (шумы)')

# %% [markdown]
# *Тренд заказов такси:*
#
#
# - На первом графике видно, что количество заказов имеет явный восходящий тренд. Со временем спрос на такси стабильно растёт, что может быть связано с сезонностью, увеличением популярности сервиса или ростом населения в зоне охвата.
#
# - Наблюдаются небольшие колебания, но в целом заказов становится всё больше.
#
#
# *Сглаженный тренд (7-дневное среднее):*
#
#
# - После сглаживания виден ещё более отчётливый рост.
#
# - В середине лета (июль-август) наблюдается заметный всплеск, что может говорить о сезонных факторах, например, увеличении числа поездок в летний период.
#
# - В конце августа тренд ускоряется — возможны дополнительные внешние факторы (начало осени, возвращение людей из отпусков).
#
#
# *Сезонность (повторяющиеся циклы в течение дня):*
#
#
# - График сезонности показывает суточные колебания.
#
# - Видны пиковые значения в определённые часы суток — скорее всего, это утренний и вечерний часы пик, когда люди едут на работу и возвращаются домой.
#
# - Спады вероятно соответствуют ночному времени, когда спрос минимален.
#
#
# *Остатки (шумы):*
#
#
# - Остатки показывают нерегулярные выбросы в данных.
#
# - Видны несколько сильных скачков вверх и вниз, что может свидетельствовать о резких изменениях спроса, возможно, из-за крупных мероприятий, погодных условий или технических сбоев в сервисе.
#
# - В конце наблюдаемого периода шум становится более выраженным, что может указывать на резкие изменения в спросе.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
#
# Желательно сначала провести декомпозицию всего ряда (изучить сезонность, тренд), а затем взять подотрезок, например: `seasonal_decompose(data).seasonal['2018-07-31':'2018-08-31']` (изучить сезонность)

# %% [markdown]
# ## Обучение

# %% [markdown]
# **Подготовка признаков**

# %%
# Функция для создания признаков, используемых при прогнозировании
def get_features(df_learning):
    # Добавляем признаки временных характеристик
    df_learning['month'] = df_learning.index.month  
    df_learning['day'] = df_learning.index.day  
    df_learning['dayofweek'] = df_learning.index.dayofweek  
    df_learning['hour'] = df_learning.index.hour 

    # Добавляем временные лаги для учёта прошлых значений заказов
    for lag in range(1, 6):  
        df_learning[f'lag_{lag}'] = df_learning['num_orders'].shift(lag)

    # Добавляем скользящее среднее для сглаживания данных
    df_learning['rolling_mean'] = df_learning['num_orders'].shift().rolling(1).mean()

    # Удаляем строки с пропущенными значениями, появившимися после создания лагов
    df_learning.dropna(inplace=True)

    return df_learning

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# При генерации новых признаков желательно написать функцию, чтобы она возвращала новый датафрейм, а не изменяла глобальную переменную.
#
# 1. Это хорошая практика (не изменять глобальные переменные внутри функции), которая улучшает читаемость кода.
# 2. В какой-то момент может появиться необходимость подбирать некоторые параметры используемые внутри функции. В этот момент копирование датасета станет обязательным.
#
#
#
#
# Для этого внутри, в начале функции нужно задать новое имя датафрейму с `df.copy()`, в нем создать новые признаки, а в конце функции возвращать через `return` этот датафрейм
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
#
# Стоит попробовать задать параметр max_lag равным 24 при создании новых признаков функцией. В случае заказов такси самая очевидная сезонность - внутри суток, а в сутках 24 часа, это значение и будет оптимальным. Размер окна тоже можно увеличить

# %%
# Копируем исходные данные перед обработкой
df_learning = df.copy()
df_learning = get_features(df_learning)

# Проверяем размеры исходного и обработанного датасетов
print("Размер исходного датасета:", df.shape)
print("Размер датасета после создания признаков:", df_learning.shape)
# Out:
# Размер исходного датасета: (4416, 1)
# Размер датасета после создания признаков: (4411, 11)

# %%
# Разделяем данные на признаки (features) и целевой признак (target)

features = df_learning.drop(['num_orders'], axis=1)  
target = df_learning['num_orders']

# %%
# Разделяем данные на обучающую и тестовую выборки
features_train, features_test, target_train, target_test = train_test_split(
    features, target, shuffle=False, test_size=0.1, random_state=17)

# Выведем размеры выборок
print("Размер обучающей выборки:", features_train.shape, target_train.shape)
print("Размер тестовой выборки:", features_test.shape, target_test.shape)
# Out:
# Размер обучающей выборки: (3969, 10) (3969,)
# Размер тестовой выборки: (442, 10) (442,)

# %% [markdown]
#  <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:  </b>
#
# Хорошо, что деление происходит последовательно по времени

# %% [markdown]
# **Обучение моделей**

# %%
# Создадим список для хранения моделей и их метрик
train_models = []

# %% [markdown]
# Линейная регрессия

# %%
# Инициализируем модель линейной регрессии
model = LinearRegression()

# Обучаем модель на обучающей выборке
model.fit(features_train, target_train)

# Делаем предсказания на обучающей выборке
predictions = model.predict(features_train)

# Вычисляем RMSE 
rmse = mean_squared_error(target_train, predictions, squared=False)

# Выводим результат
print(f'RMSE линейной регрессии на обучающей выборке: {rmse:.2f}')

# Добавляем модель и её RMSE в список обученных моделей
train_models.append(["Linear Regression", model, rmse])
# Out:
# RMSE линейной регрессии на обучающей выборке: 30.49

# %% [markdown]
# Дерево решений

# %%
# Инициализируем модель дерева решений
model = DecisionTreeRegressor(random_state=12345)

# Определяем диапазон гиперпараметров для подбора
parameters = {'max_depth': range(1, 11, 2)}

# Используем кросс-валидацию для временных рядов (разбиваем на 2 части)
tscv = TimeSeriesSplit(n_splits=2)

# Инициализируем GridSearchCV для подбора лучшей глубины дерева
gsearch = GridSearchCV(estimator=model, cv=tscv, param_grid=parameters)

# Обучаем модель с подбором гиперпараметров
gsearch.fit(features_train, target_train)

# Выводим наилучший параметр max_depth
best_params = gsearch.best_params_
print(f'Лучший параметр для Decision Tree: {best_params}')

# Делаем предсказания на обучающей выборке с лучшей моделью
predictions = gsearch.predict(features_train)

# Вычисляем RMSE 
rmse = mean_squared_error(target_train, predictions, squared=False)

# Выводим результат
print(f'RMSE Decision Tree на обучающей выборке: {rmse:.2f}')

# Добавляем модель и её RMSE в список обученных моделей
train_models.append(["Decision Tree", gsearch.best_estimator_, rmse])
# Out:
# Лучший параметр для Decision Tree: {'max_depth': 7}
# RMSE Decision Tree на обучающей выборке: 22.02

# %% [markdown]
#  <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:  </b>
#
# Отлично, что применяется TimeSeriesSplit, а не простой сплиттер

# %% [markdown]
# Случайный лес

# %%
# Инициализируем модель случайного леса
model = RandomForestRegressor(random_state=12345)

# Определяем диапазон гиперпараметров для подбора
parameters = {
    'n_estimators': range(50, 100, 10),  
    'max_depth': range(1, 11, 2)  
}

# Используем кросс-валидацию для временных рядов (разбиваем на 2 части)
tscv = TimeSeriesSplit(n_splits=2)

# Инициализируем GridSearchCV для подбора лучших гиперпараметров
gsearch = GridSearchCV(estimator=model, cv=tscv, param_grid=parameters, n_jobs=-1)

# Обучаем модель с подбором лучших параметров
gsearch.fit(features_train, target_train)

# Выводим наилучшие гиперпараметры для случайного леса
best_params = gsearch.best_params_
print(f'Лучшие параметры для Random Forest: {best_params}')

# Делаем предсказания на обучающей выборке с оптимальной моделью
predictions = gsearch.predict(features_train)

# Вычисляем RMSE 
rmse = mean_squared_error(target_train, predictions, squared=False)

# Выводим результат RMSE
print(f'RMSE Random Forest на обучающей выборке: {rmse:.2f}')

# Добавляем модель и её RMSE в список обученных моделей
train_models.append(["Random Forest", gsearch.best_estimator_, rmse])
# Out:
# Лучшие параметры для Random Forest: {'max_depth': 9, 'n_estimators': 90}
# RMSE Random Forest на обучающей выборке: 16.99

# %% [markdown]
# CatBoost Regressor

# %%
# Инициализируем модель CatBoost
model = CatBoostRegressor(verbose=False, random_state=12345)

# Обучаем модель на обучающей выборке
model.fit(features_train, target_train, verbose=False)

# Делаем предсказания на обучающей выборке
predictions = model.predict(features_train)

# Вычисляем RMSE
rmse = mean_squared_error(target_train, predictions, squared=False)

# Выводим результат RMSE
print(f'RMSE CatBoost на обучающей выборке: {rmse:.2f}')

# Добавляем модель и её RMSE в список обученных моделей
train_models.append(["CatBoost", model, rmse])
# Out:
# RMSE CatBoost на обучающей выборке: 13.32

# %% [markdown]
# LightGBM Regressor

# %%
# Инициализируем модель LightGBM
model = lgb.LGBMRegressor(random_state=12345, verbose=-1)

# Обучаем модель на обучающей выборке
model.fit(features_train, target_train, verbose=False)

# Делаем предсказания на обучающей выборке
predictions = model.predict(features_train)

# Вычисляем RMSE
rmse = mean_squared_error(target_train, predictions, squared=False)

# Выводим результат RMSE
print(f'RMSE LightGBM на обучающей выборке: {rmse:.2f}')

# Добавляем модель и её RMSE в список обученных моделей
train_models.append(["LightGBM", model, rmse])
# Out:
# RMSE LightGBM на обучающей выборке: 14.96

# %%
# Сохранение результатов в таблицу

# Преобразуем список с моделями и их RMSE в датафрейм
result = pd.DataFrame(train_models, columns=['Model', 'Trained Model', 'RMSE (Train)'])
result = result.drop(columns=['Trained Model'])

# Настроим отображение: убираем ограничение на ширину столбцов
pd.options.display.max_colwidth = None

# Сортируем таблицу по RMSE, чтобы увидеть лучшие модели
result = result.sort_values(by='RMSE (Train)')

# Выводим отсортированные результаты
display(result)
# Out:
#                Model  RMSE (Train)
# 3           CatBoost     13.317990
# 4           LightGBM     14.964693
# 2      Random Forest     16.987254
# 1      Decision Tree     22.023192
# 0  Linear Regression     30.494235

# %% [markdown]
#  <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:  </b>
#
# Молодец, что пробуешь разные модели в этом шаге)
# </div>

# %% [markdown]
# ## Тестирование

# %%
# Тестирование обученных моделей на тестовых данных

# Создадим список для хранения результатов тестирования
test_models = []

# Функция для отображения предсказаний модели и вычисления RMSE
def display_result(target, pred, model_name, rmse):
    """
    Функция строит красивый график фактических и предсказанных значений,
    а также выводит RMSE.
    """
    result = target.to_frame().reset_index() 
    result['prediction'] = pd.Series(pred) 
    result.set_index('datetime', inplace=True)

    # Визуализация 
    plt.figure(figsize=(15, 5))
    sns.set_style("whitegrid") 
    sns.set_palette("pastel")
    plt.plot(result.index, result['num_orders'], label='Фактические значения', color=sns.color_palette("pastel")[0], linewidth=2)
    plt.plot(result.index, result['prediction'], label='Предсказания', color=sns.color_palette("pastel")[3], linestyle='dashed', linewidth=2)

    # Настройка заголовка и подписей осей
    plt.title(f'{model_name} - RMSE={rmse:.2f}', fontsize=14, fontweight='bold', color='darkblue')
    plt.xlabel('Дата', fontsize=12, color='black')
    plt.ylabel('Количество заказов', fontsize=12, color='black')
    plt.xticks(rotation=25)
    
    # Добавляем легенду и сетку
    plt.legend(fontsize=12)
    plt.grid(alpha=0.3)

    # Отображаем график
    plt.show()

# Тестируем все обученные модели на тестовой выборке
for model_name, trained_model, _ in train_models:
    predictions = trained_model.predict(features_test)  # Предсказания модели
    rmse = mean_squared_error(target_test, predictions, squared=False)  # Вычисляем RMSE

    # Визуализируем результат предсказаний
    display_result(target_test, predictions, model_name, rmse)

    # Добавляем RMSE в список результатов тестирования
    test_models.append([model_name, rmse])

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# На тестовой выборке получено хорошее качество (она у нас играет роль отложенной, holdout), но знай, что тестирование положено проводить для одной лучшей модели. На предыдущем шаге мы должны были настроить модели и выбрать одну наилучшую, опираясь на метрики данные заказчиком (это может быть качество, время обучения, скорость предсказания и т.д.). Тестированием мы моделируем работу модели на новых незнакомых ей данных, которые ни разу не использовались ни при тренировке, ни при валидации, и проверяем, не словили ли мы переобучение. А эти данные могут быть смещенными, с выбросами и т.д. То есть по таким данным некорректно заново переопределять модель-победитель.  Советую тебе статью, рассматривающую разные способы валидации моделей машинного обучения: https://www.maartengrootendorst.com/blog/validate/
#
# Метрики качества на тестовой выборке для всех моделей можно вычислить только с целью исследования их смещения относительно аналогичных метрик на кросс-валидации/ валидационной выборке. Но это не означает, что модель-победитель должна выбираться исходя из сравнения метрик, полученных на тестовой выборке.

# %%
# Преобразуем результаты тестирования в датафрейм
test_results = pd.DataFrame(test_models, columns=['Model', 'RMSE (Test)'])

# Сортируем результаты по RMSE для наглядности
test_results = test_results.sort_values(by='RMSE (Test)')

# Выводим результаты
display(test_results)
# Out:
#                Model  RMSE (Test)
# 3           CatBoost    44.406829
# 4           LightGBM    44.695506
# 2      Random Forest    49.246222
# 0  Linear Regression    52.692761
# 1      Decision Tree    60.488801

# %%
# Добавляем RMSE на тестовой выборке в датафрейм с результатами обучения
result['RMSE (Test)'] = pd.Series([rmse for _, rmse in test_models])

# Сортируем по RMSE на тестовой выборке, чтобы увидеть лучшие модели
result = result.sort_values(by='RMSE (Test)')

# Выводим результат
display(result)
# Out:
#                Model  RMSE (Train)  RMSE (Test)
# 3           CatBoost     13.317990    44.406829
# 4           LightGBM     14.964693    44.695506
# 2      Random Forest     16.987254    49.246222
# 0  Linear Regression     30.494235    52.692761
# 1      Decision Tree     22.023192    60.488801

# %% [markdown]
# **Выводы:**
#
#
# - CatBoost показал лучший баланс между переобучением и точностью на тесте. Это делает его лучшей моделью для прогнозирования количества заказов такси.
#
#
# - LightGBM оказался чуть хуже, но разница минимальна, что делает его тоже хорошим вариантом.
#
#
# - Random Forest справился средне, что говорит о том, что ансамблирование деревьев уступает бустингу в задаче временных рядов.
#
#
# - Линейная регрессия и Decision Tree плохо справляются, так как они не способны учитывать сложные временные зависимости.

# %% [markdown]
#  <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:  </b>
#
# Отлично, что  визуализированы результаты, показаны предсказанные значения лучшей модели и реальные тестовые

# %% [markdown]
# ## Итоги проекта

# %% [markdown]
# Компания «Чётенькое такси» собрала исторические данные о заказах такси в аэропортах. Основная задача заключалась в том, чтобы разработать *модель прогнозирования количества заказов такси на следующий час*. Это позволит компании эффективнее распределять водителей в периоды пиковой нагрузки.
#
#
# Требуемый уровень качества модели — *RMSE не более 48* на тестовой выборке.

# %% [markdown]
# *Этапы работы:*
#
#
# 1. Предобработка данных
#
#
# - Загружены и проанализированы данные о заказах такси.
#
# - Пропущенные значения отсутствуют, индекс временного ряда монотонный.
#
# - Проведено ресемплирование данных по одному часу для унификации временного ряда.
#
#
# 2. Анализ данных
#
#
# - Выявлены тренды: количество заказов стабильно увеличивается.
#
# - Определена выраженная сезонность (суточные колебания спроса).
#
# - Найдены выбросы и шумы, которые могут быть связаны с особыми событиями или погодными условиями.
#
#
# 3. Создание признаков
#
#
# - Добавлены временные признаки: месяц, день, день недели, час.
#
# - Созданы лаговые признаки (предыдущие значения заказов).
#
# - Вычислено скользящее среднее, чтобы учесть краткосрочные тенденции.
#
#
# 4. Обучены пять моделей:
#
#
# - Linear Regression
#
# - Decision Tree
#
# - Random Forest
#
# - CatBoost
#
# - LightGBM
#
#
# Проведён GridSearchCV для подбора оптимальных гиперпараметров.
#
#
# 5. Тестирование моделей
#
# - Оценена точность моделей на тестовых данных.
#
# - Построены графики фактических и предсказанных значений.
#
# - Сравнены RMSE моделей на обучающей и тестовой выборках.

# %%
result['RMSE (Test)'] = pd.Series([rmse for _, rmse in test_models])

result = result.sort_values(by='RMSE (Test)')

def highlight_best_models(val):
    return f"✅ {val:.2f}" if val <= 48 else f"{val:.2f}"

styled_result = result.style.format({
    'RMSE (Train)': "{:.2f}",
    'RMSE (Test)': highlight_best_models
}).set_caption("<b>Результаты тестирования</b>")

display(styled_result)
# Out:
# <style  type="text/css" >
# </style><table id="T_50e94_" ><caption><b>Результаты тестирования</b></caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >RMSE (Train)</th>        <th class="col_heading level0 col2" >RMSE (Test)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_50e94_level0_row0" class="row_heading level0 row0" >3</th>
#                         <td id="T_50e94_row0_col0" class="data row0 col0" >CatBoost</td>
#                         <td id="T_50e94_row0_col1" class="data row0 col1" >13.32</td>
#                         <td id="T_50e94_row0_col2" class="data row0 col2" >✅ 44.41</td>
#             </tr>
#             <tr>
#                         <th id="T_50e94_level0_row1" class="row_heading level0 row1" >4</th>
#                         <td id="T_50e94_row1_col0" class="data row1 col0" >LightGBM</td>
# ...

# %% [markdown]
# - **CatBoost** показал наилучший результат (RMSE = 44.41) и продемонстрировал лучший баланс между обучением и тестированием, что делает его оптимальным выбором.
#
#
# - **LightGBM** занял второе место (RMSE = 44.70) с минимальной разницей, что делает его достойной альтернативой.
#
#
# - Random Forest, Decision Tree и Linear Regression оказались менее точными и не достигли целевого RMSE ≤ 48.

# %% [markdown]
# *Главное достижение — удалось построить модель, соответствующую требованиям: RMSE на тесте < 48 (CatBoost и LightGBM).*
#
#
# CatBoost рекомендуется для внедрения, так как он продемонстрировал лучшую точность при минимальном переобучении. LightGBM также подходит как альтернативное решение, так как его качество почти идентично CatBoost.

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
#
# <h2> Итоговый комментарий ревьюера <a class="tocSkip"> </h2>
#
# У меня сложилось отличное общее впечатление о проекте, тебе удалось неплохо справиться с этим проектом. Молодец! Подготовлены данные для анализа, изучен каждый параметр. Все красиво визуализировано, построено несколько моделей регрессии и оценено их качество. Осмысленная аналитика и дельная модельная работа - многое удалось как надо)
#
# Отмечу отдельные положительные моменты проекта🙂:
#
# - в ходе проекта встречались функции, помогающие избавиться от дублирования кода;
# - много красивых визуализаций в проекте и хорошая интерпретация;
# - при обучении моделей использована валидация и поиск гиперпараметров.
#
# Принимаю работу)
#
# Если хочешь лучше разобраться в теме, то могу посоветовать тебе:
#
# Полезная лекция про временные ряды: https://www.youtube.com/watch?v=u433nrxdf5k
#
# Б.Б. Демешев - временные ряды https://disk.yandex.ru/i/LiDHB-B3A6Lz5A
#
# Базовое применение ARIMA - https://colab.research.google.com/drive/17RnG91Eq8JBKyxToNzvCvjibfxum-oPj?usp=sharing
#
# Канторович - Анализ временных рядов https://yadi.sk/i/IOkUOS3hTXf3gg
# https://facebook.github.io/prophet/
#
# https://facebook.github.io/prophet/docs/quick_start.html#python-api
#
# https://nbviewer.jupyter.org/github/miptgirl/habra_materials/blob/master/prophet/habra_data.ipynb
#
#
#
# В этом проекте были отработаны все моменты. Если у тебя остались вопросы, то можно обратиться ко мне через куратора или напрямую адресовать вопросы преподавателю в тред.
#
# Успехов тебе в следующем спринте!
#
# Рад был помочь тебе)
#
# **Буду очень благодарен, если ты поставишь мне положительную оценку за проект в форме на странице курса, это важно для меня. Достаточно поставить оценку, а комментарий можешь написать по желанию:)**
#
# </div>

# %% [markdown]
# ## Чек-лист проверки

# %% [markdown]
# - [x]  Jupyter Notebook открыт
# - [x]  Весь код выполняется без ошибок
# - [x]  Ячейки с кодом расположены в порядке исполнения
# - [x]  Данные загружены и подготовлены
# - [x]  Данные проанализированы
# - [x]  Модель обучена, гиперпараметры подобраны
# - [x]  Качество моделей проверено, выводы сделаны
# - [x]  Значение *RMSE* на тестовой выборке не больше 48
